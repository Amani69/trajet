# %%
from math import radians, cos, sin, asin, sqrt
from pyspark.sql.functions import isnan, when, count, col,round
from pyspark.sql import Window
import pyspark.sql.functions as F
import numpy as np
import matplotlib.pyplot as plt
from pyspark.ml.stat import Correlation
from pyspark.ml.linalg import DenseMatrix, Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_dico = {}
for n in [2018,2019,2020,2021]:  
    path = f"/mnt/datalake/tmp/guillaume/profiling/production/raw_data/{n}_raw_data_user"
    df_dico[n] = spark.read.option("header",True).option("inferSchema",True).csv(path)
df_dico[2022]=df_2022
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
def get_distance(longit_a, latit_a, longit_b, latit_b):
  # Transform to radians
  longit_a, latit_a, longit_b, latit_b = map(radians, [longit_a, latit_a, longit_b, latit_b])
  dist_longit = longit_b - longit_a
  dist_latit = latit_b - latit_a
  # Calculate area
  area = sin(dist_latit / 2) ** 2 + cos(latit_a) * cos(latit_b) * sin(dist_longit / 2) ** 2
  # Calculate the central angle
  central_angle = 2 * asin(sqrt(area))
  radius = 6371
  # Calculate Distance 
  distance = central_angle * radius
  return abs(distance)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for n in [2018,2019,2020,2021]: 
  w = Window().partitionBy("rideid").orderBy(col("deviceid").asc(), col("dateentry").asc())
  df_dico[n] = df_dico[n].select("*", lag("dateentry").over(w).alias("previousDateentry")).na.drop()
  df_dico[n]= df_dico[n].select("*", lag("deviceid").over(w).alias("previousDeviceid")).na.drop()
  df_dico[n] = df_dico[n].select("*", lag("latitude").over(w).alias("previousLatitude")).na.drop()
  df_dico[n] = df_dico[n].select("*", lag("longitude").over(w).alias("previousLongitude")).na.drop()
  df_dico[n] = df_dico[n].select("*", lag("speed").over(w).alias("previousSpeed")).na.drop()
  df_dico[n]= df_dico[n].withColumn("distance",get_distance(df_dico[n].longitude,df_dico[n].latitude, df_dico[n].previousLongitude, df_dico[n].previousLatitude))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3011549011914802&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">for</span> n <span class="ansi-green-fg">in</span> <span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">2018</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">2019</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">2020</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">2021</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>   w <span class="ansi-blue-fg">=</span> Window<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>partitionBy<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;rideid&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>orderBy<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;deviceid&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>asc<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> col<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dateentry&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>asc<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg">   </span>df_dico<span class="ansi-blue-fg">[</span>n<span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> df_dico<span class="ansi-blue-fg">[</span>n<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;*&#34;</span><span class="ansi-blue-fg">,</span> lag<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dateentry&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>over<span class="ansi-blue-fg">(</span>w<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>alias<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;previousDateentry&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>na<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>   df_dico<span class="ansi-blue-fg">[</span>n<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">=</span> df_dico<span class="ansi-blue-fg">[</span>n<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;*&#34;</span><span class="ansi-blue-fg">,</span> lag<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;deviceid&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>over<span class="ansi-blue-fg">(</span>w<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>alias<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;previousDeviceid&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>na<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>   df_dico<span class="ansi-blue-fg">[</span>n<span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> df_dico<span class="ansi-blue-fg">[</span>n<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;*&#34;</span><span class="ansi-blue-fg">,</span> lag<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;latitude&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>over<span class="ansi-blue-fg">(</span>w<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>alias<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;previousLatitude&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>na<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">drop</span><span class="ansi-blue-fg">(self, how, thresh, subset)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2951</span>
# <span class="ansi-green-intense-fg ansi-bold">   2952</span>     <span class="ansi-green-fg">def</span> drop<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> how<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;any&#39;</span><span class="ansi-blue-fg">,</span> thresh<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">None</span><span class="ansi-blue-fg">,</span> subset<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">None</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 2953</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>df<span class="ansi-blue-fg">.</span>dropna<span class="ansi-blue-fg">(</span>how<span class="ansi-blue-fg">=</span>how<span class="ansi-blue-fg">,</span> thresh<span class="ansi-blue-fg">=</span>thresh<span class="ansi-blue-fg">,</span> subset<span class="ansi-blue-fg">=</span>subset<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2954</span>
# <span class="ansi-green-intense-fg ansi-bold">   2955</span>     drop<span class="ansi-blue-fg">.</span>__doc__ <span class="ansi-blue-fg">=</span> DataFrame<span class="ansi-blue-fg">.</span>dropna<span class="ansi-blue-fg">.</span>__doc__
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">dropna</span><span class="ansi-blue-fg">(self, how, thresh, subset)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2174</span>             thresh <span class="ansi-blue-fg">=</span> len<span class="ansi-blue-fg">(</span>subset<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">if</span> how <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#39;any&#39;</span> <span class="ansi-green-fg">else</span> <span class="ansi-cyan-fg">1</span>
# <span class="ansi-green-intense-fg ansi-bold">   2175</span>
# <span class="ansi-green-fg">-&gt; 2176</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>na<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span>thresh<span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>_jseq<span class="ansi-blue-fg">(</span>subset<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)

# %%
df_dico.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: dict_keys([2018, 2019, 2020, 2021, 2022])</div>

# %%
def all_data():
  df1=df_dico[2018].union(df_dico[2019])
  df2=df1.union(df_dico[2020])
  df3=df2.union(df_dico[2021])
  df4=df3.union(df_dico[2022])
  return df4
df=all_data()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.write.option('header',True).mode('overwrite').parquet('/mnt/datalake/tmp/amani/ride_data/all_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data=df.select("*")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Convert dateentry to date
#add month and week
def get_date(data):
  data=(data.withColumn("date", F.to_date(F.from_unixtime(F.col('dateentry')/1000)))
                     .withColumn("month",F.month("date"))
                     .withColumn("week",F.weekofyear("date"))
                     .withColumn("year",F.year("date"))
                     )
  return data
data_date=get_date(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_date.groupby(F.col("year")).count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>count</th></tr></thead><tbody><tr><td>2018</td><td>22085962</td></tr><tr><td>2019</td><td>116215042</td></tr><tr><td>2020</td><td>73547493</td></tr><tr><td>2021</td><td>88247623</td></tr><tr><td>2022</td><td>5837433</td></tr><tr><td>1999</td><td>399</td></tr></tbody></table></div>

# %%
data_date.filter(F.col("year")==2018).groupby(F.col('month')).count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th></tr></thead><tbody><tr><td>12</td><td>3411590</td></tr><tr><td>6</td><td>1811238</td></tr><tr><td>3</td><td>107387</td></tr><tr><td>5</td><td>2781580</td></tr><tr><td>9</td><td>2048537</td></tr><tr><td>4</td><td>591475</td></tr><tr><td>8</td><td>1205226</td></tr><tr><td>7</td><td>1782503</td></tr><tr><td>10</td><td>4570599</td></tr><tr><td>11</td><td>3662103</td></tr><tr><td>2</td><td>113724</td></tr></tbody></table></div>

# %%
data_date.filter(F.col("year")==2019).groupby(F.col('month')).count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th></tr></thead><tbody><tr><td>12</td><td>9211268</td></tr><tr><td>1</td><td>2543915</td></tr><tr><td>6</td><td>15380062</td></tr><tr><td>3</td><td>2347998</td></tr><tr><td>5</td><td>17569262</td></tr><tr><td>9</td><td>12354407</td></tr><tr><td>4</td><td>4148194</td></tr><tr><td>8</td><td>13887572</td></tr><tr><td>7</td><td>15968544</td></tr><tr><td>10</td><td>11902924</td></tr><tr><td>11</td><td>8916312</td></tr><tr><td>2</td><td>1984584</td></tr></tbody></table></div>

# %%
data_date.filter(F.col("year")==2020).groupby(F.col('month')).count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th></tr></thead><tbody><tr><td>12</td><td>7166039</td></tr><tr><td>1</td><td>8687321</td></tr><tr><td>6</td><td>4486570</td></tr><tr><td>3</td><td>4497297</td></tr><tr><td>5</td><td>3077598</td></tr><tr><td>9</td><td>8015044</td></tr><tr><td>4</td><td>1463472</td></tr><tr><td>8</td><td>6310172</td></tr><tr><td>7</td><td>7000627</td></tr><tr><td>10</td><td>9609383</td></tr><tr><td>11</td><td>5467626</td></tr><tr><td>2</td><td>7766344</td></tr></tbody></table></div>

# %%
data_date.filter(F.col("year")==2021).groupby(F.col('month')).count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th></tr></thead><tbody><tr><td>12</td><td>7255888</td></tr><tr><td>1</td><td>6405108</td></tr><tr><td>6</td><td>6975385</td></tr><tr><td>3</td><td>7596965</td></tr><tr><td>5</td><td>7214109</td></tr><tr><td>9</td><td>7104728</td></tr><tr><td>4</td><td>6059603</td></tr><tr><td>8</td><td>5498532</td></tr><tr><td>7</td><td>5963981</td></tr><tr><td>10</td><td>11662326</td></tr><tr><td>11</td><td>9537439</td></tr><tr><td>2</td><td>6973559</td></tr></tbody></table></div>

# %%
data_date.filter(F.col("year")==2022).groupby(F.col('month')).count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>4512197</td></tr><tr><td>2</td><td>1325236</td></tr></tbody></table></div>

# %%
data_date=data_date.filter(F.col("year")!=1999)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#le nombre de km qui ont fait tt  utilisateurs , chaque mois de tt les années
data_group_mois=data_date.sort(data_date["date"].asc()).groupby("year","month").agg(F.count("rideid").alias('nombre_trajet'), F.avg("speed").alias('vitesse_moyenne'), F.avg("acceleration").alias('acceleration_moyenne'),F.sum("distance").alias('distance_totale'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_group_mois.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 49</div>

# %%
data_group_mois.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>month</th><th>nombre_trajet</th><th>vitesse_moyenne</th><th>acceleration_moyenne</th><th>distance_totale</th></tr></thead><tbody><tr><td>2018</td><td>8</td><td>1205226</td><td>12.557313261672364</td><td>-0.009592415455328407</td><td>24011.442336515414</td></tr><tr><td>2018</td><td>9</td><td>2048537</td><td>14.825691508825201</td><td>-0.04451394014317825</td><td>77144.17659856532</td></tr><tr><td>2018</td><td>11</td><td>3662103</td><td>11.09088239474113</td><td>-0.018484770612614002</td><td>312212.45671821054</td></tr><tr><td>2019</td><td>1</td><td>2543915</td><td>11.276647377424105</td><td>-0.019592059039573652</td><td>308256.4557960545</td></tr><tr><td>2019</td><td>4</td><td>4148194</td><td>11.18286367197584</td><td>0.024486492900499555</td><td>105872.83663160302</td></tr><tr><td>2019</td><td>5</td><td>17569262</td><td>11.887574156232544</td><td>0.035374619545609366</td><td>327625.3884468386</td></tr><tr><td>2019</td><td>6</td><td>15380062</td><td>11.94688006426731</td><td>0.0380609085594971</td><td>277400.9113236109</td></tr><tr><td>2019</td><td>7</td><td>15968544</td><td>12.594470186257212</td><td>0.03936647000843744</td><td>294604.14560322696</td></tr><tr><td>2019</td><td>8</td><td>13887572</td><td>13.487897264576986</td><td>0.04200577509289885</td><td>276196.8432015655</td></tr><tr><td>2019</td><td>9</td><td>12354407</td><td>11.919281155455032</td><td>0.03628058994048515</td><td>221903.2420182675</td></tr><tr><td>2019</td><td>10</td><td>11902924</td><td>12.015593207952193</td><td>0.03679185012377977</td><td>210542.7323917703</td></tr><tr><td>2019</td><td>11</td><td>8916312</td><td>11.890917175320773</td><td>0.03327551172482247</td><td>
count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 214</div>

# %%
#dataset=data_group_mois.select("nombre_trajet","vitesse_moyenne","distance_totale","acceleration_moyenne")
dataset=data_group_semaine.select("nombre_device","vitesse_moyenne","distance_totale","acceleration_moyenne")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import six
for i in dataset.columns:
    if not( isinstance(dataset.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to distance for ", i, dataset.stat.corr("distance_totale",i))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Correlation to distance for  nombre_trajet 0.664352990867555
# Correlation to distance for  vitesse_moyenne 0.3858458783892261
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# def correlation(df):
#   assembler = VectorAssembler(inputCols=df.columns, outputCol="features",handleInvalid='keep')
#   df_assembler = assembler.transform(df).select("features")
#   # correlation will be in Dense Matrix
#   correlation = Correlation.corr(df_assembler ,"features","pearson").collect()[0][0]

#   # To convert Dense Matrix into DataFrame
#   rows = correlation.toArray().tolist()
#   df_assembler = spark.createDataFrame(rows,df.columns)
#   return df_assembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# df_corr=correlation(dataset)
# df_corr.display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
trainDF, testDF = dataset.randomSplit([0.8, 0.2], seed=42)
print(trainDF.cache().count()) # Cache because accessing training data multiple times
print(testDF.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">175
# 33
# </div>

# %%
from pyspark.ml.feature import VectorAssembler,StringIndexer
from pyspark.ml.feature import StandardScaler
features = dataset.drop('distance_totale').columns
vector = VectorAssembler(inputCols=features, outputCol='features')
scale=StandardScaler(inputCol='features',outputCol='standardized')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.regression import LinearRegression 
# lr = LinearRegression(featuresCol ='features', labelCol ='distance_totale') 
lr = LinearRegression(featuresCol = 'features', labelCol='distance_totale', maxIter=10, regParam=0.3, elasticNetParam=0.8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml import Pipeline
 
# Define the pipeline based on the stages created in previous steps.
pipeline = Pipeline(stages=[vector,scale, lr ])
 
# Define the pipeline model.
pipelineModel = pipeline.fit(trainDF)
 
# Apply the pipeline model to the test dataset.
predDF = pipelineModel.transform(testDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predDF .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre_trajet</th><th>vitesse_moyenne</th><th>distance_totale</th><th>acceleration_moyenne</th><th>features</th><th>standardized</th><th>prediction</th></tr></thead><tbody><tr><td>24810</td><td>7.115424419010222</td><td>391.575320857469</td><td>-0.00789465637434872</td><td>Map(vectorType -> dense, length -> 3, values -> List(24810.0, 7.115424419010222, -0.00789465637434872))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.02524853758563222, 3.6493509291320936, -0.385670143602081))</td><td>1259.2009964302924</td></tr><tr><td>31311</td><td>8.567968949477258</td><td>489.7150445518909</td><td>-0.0039010767091389523</td><td>Map(vectorType -> dense, length -> 3, values -> List(31311.0, 8.567968949477258, -0.0039010767091389523))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.03186444822022291, 4.394330345637931, -0.19057559230885096))</td><td>3761.391542089783</td></tr><tr><td>31770</td><td>5.640765236695341</td><td>614.932538936557</td><td>-0.01882693221740406</td><td>Map(vectorType -> dense, length -> 3, values -> List(31770.0, 5.640765236695341, -0.01882693221740406))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.03233156143069471, 2.89302937468537, -0.9197342237041791))</td><td>971.4609520494196</td></tr><tr><td>200516</td><td>11.366885508850165</td><td>10202.324693246854</td><td>-0.023535729869764724</td><td>Map(vectorType -> dense, length -> 3, values -> List(200516.0, 11.366885508850165, -0.023535729869764724))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.20406028869490653, 5.829835544628092, -1.1497686394742885))</td><td>19192.808375706976</td></tr><tr><td>265527</td><td>10.41113688431276</td><td>4078.643474926213</td><td>-0.01278505609743703</td><td>Map(vectorType -> dense, length -> 3, values -> List(265527.0, 10.41113688431276, -0.01278505609743703))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.27022041271665326, 5.339652257506974, -0.6245761927118677))</td><td>14709.05224323125</td></tr><tr><td>287213</td><td>13.32213473467826</td><td>5964.592371321811</td><td>-0.007086963144759914</td><td>Map(vectorType -> dense, length -> 3, values -> List(287213.0, 13.32213473467826, -0.007086963144759914))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.2922897309787258, 6.8326415838429835, -0.3462126740085876))</td><td>20544.994659883116</td></tr><tr><td>358532</td><td>11.806647296464524</td><td>6938.092065068921</td><td>0.008299259371928864</td><td>Map(vectorType -> dense, length -> 3, values -> List(358532.0, 11.806647296464524, 0.008299259371928864))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.36486935419798033, 6.055380079110055, 0.40543582924808097))</td><td>13413.587655494095</td></tr><tr><td>409318</td><td>10.559068399735938</td><td>6962.042194214638</td><td>-0.0069414941369470495</td><td>Map(vectorType -> dense, length -> 3, values -> List(409318.0, 10.559068399735938, -0.0069414941369470495))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.4165530393984607, 5.415523207919317, -0.3391062148452566))</td><td>15666.56101114134</td></tr><tr><td>540623</td><td>10.531438948783565</td><td>38998.452033274516</td><td>0.0071581187644733394</td><td>Map(vectorType -> dense, length -> 3, values -> List(540623.0, 10.531438948783565, 0.0071581187644733394))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.5501789655444276, 5.401352645972925, 0.34968877186157815))</td><td>13548.898917388444</td></tr><tr><td>553349</td><td>12.992028659327262</td><td>18941.78569302243</td><td>-0.02384694648234447</td><td>Map(vectorType -> dense, length -> 3, values -> List(553349.0, 12.992028659327262, -0.02384694648234447))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.5631299082818221, 6.663337148597239, -1.1649722088221548))</td><td>28983.195913023577</td></tr><tr><td>556794</td ...

# %%
from pyspark.ml.evaluation import RegressionEvaluator
lr_evaluator = RegressionEvaluator(predictionCol="prediction", \
                 labelCol='distance_totale',metricName="r2")
print("R Squared (R2) on test data = %g" % lr_evaluator.evaluate(predDF))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">  File &#34;/databricks/python_shell/scripts/PythonShellImpl.py&#34;, line 837, in autoComplete
#     completions = self.shell.completion_with_jedi(
#   File &#34;/databricks/python_shell/scripts/PythonShellImpl.py&#34;, line 680, in completion_with_jedi
#     completions = list(self.Completer.completions(full_text, full_text_cursor_pos))
#   File &#34;/databricks/python/lib/python3.8/site-packages/IPython/core/completer.py&#34;, line 1837, in completions
#     for c in self._completions(text, offset, _timeout=self.jedi_compute_type_timeout/1000):
#   File &#34;/databricks/python/lib/python3.8/site-packages/IPython/core/completer.py&#34;, line 1897, in _completions
#     yield Completion(start=offset - delta,
#   File &#34;/databricks/python/lib/python3.8/site-packages/IPython/core/completer.py&#34;, line 377, in __init__
#     warnings.warn(&#34;``Completion`` is a provisional API (as of IPython 6.0). &#34;
# ``Completion`` is a provisional API (as of IPython 6.0). It may change without warnings. Use in corresponding context manager.R Squared (R2) on test data = 0.27158
# </div>

# %%
# test_result =lr_evaluator.evaluate(testDF)
# print("Root Mean Squared Error (RMSE) on test data = %g" % test_result.rootMeanSquaredError)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# #### Pandas

# %%
df_pandas=data_group_semaine.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df=df_pandas.copy()
